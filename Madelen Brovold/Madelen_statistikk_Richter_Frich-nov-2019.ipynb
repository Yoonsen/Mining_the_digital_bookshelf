# %% [markdown]
# # Statistikk fra Bokhylla på _jøde_
#
# Bare hopp over den første biten til dere kommer til en neste hovedoverskrift. Deretter kan narrative følges.
#
# Kollokasjoner for Øvre Richter Frich

# %%
from dhlab.module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ##### Module imports

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import networkx as nx
from dhlab.graph_networkx_louvain import cutdown, make_collocation_graph
import pandas as pd
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Bygg korpus og analysér
#
# Hent URN-er fra tekst eller metadata. URNene representer korpuset, eller en definisjon av korpuset. Korpuset bygges med ordene som metadata lagt inn i variabelen `words`. Korpusets URNer ligger i variabelen `korpusår`.

# %%
words = """Hebræer Hebræeren Hebræere Hebræerne
hebræer hebræeren hebræere hebræerne
Hebreer Hebreeren Hebreere Hebreerne
hebreer hebreeren hebreere hebreerne
Israelit Israeliten Israeliter Israeliterne Israelitene
israelit israeliten israeliter israeliterne israelitene
Israelitt Israelitten Israelitter Israelitterne Israelittene
israelitt israelitten israelitter israelitterne israelittene​
Mosait Mosaiten Mosaiter Mosaiterne Mosaitene
mosait mosaiten mosaiter mosaiterne mosaitene
Mosaitt Mosaitten Mosaitter Mosaitterne Mosaittene
mosaitt mosaitten mosaitter mosaitterne mosaittene
Jødebolsjevik Jødebolsjeviken Jødebolsjeviker Jødebolsjevikerne Jødebolsjevikene
jødebolsjevik jødebolsjeviken jødebolsjeviker jødebolsjevikerne jødebolsjevikene""".split()
words = words + [x.capitalize() for x in words]

# %%
Richterkorpus_def = nb.get_urn({'author':'%frich%richter%', 'limit':200})
len(Richterkorpus_def)
# Out:
# 97

# %%
aggs = nb.get_aggregated_corpus(Richterkorpus_def)

# %% [markdown]
# ## Kollokasjoner
#
# Her kjøres kollokasjoner for ord med forskjellige krav til frekvens.

# %% [markdown]
# ### Kollokasjoner for n=5
#
# For å være med i kollokasjonene kreves at ordet forekommer minst 6 ganger i hele korpuset

# %%
colls = nb.urn_coll_words(words, urns=Richterkorpus_def )

# %%
nb.normalize_corpus_dataframe(colls)
nb.normalize_corpus_dataframe(aggs)
# Out:
# True

# %%
3/len(aggs)
# Out:
# 1.6098998105684556e-05

# %%
colls_top = pd.DataFrame(colls[0]**1.01/(aggs[aggs[0] > 0.00000016][0])).sort_values(by=0, ascending=False)

# %%
print(', '.join(list(colls_top.index[:250])))
# Out:
# bedstefædre, mandsperson., iLe6re, paatruffet, forestillingen, lystne, utdød, elskelige, paatrængende, påtrengende, mistenksomt, koster, adskilte, tilsengs, etterlot, dragt, efterlot, fe, karakteristisk, yngre, utvilsomt, mellemrum, overrasket, saaledes, naadde, lykkelig, enkelte, saaes, gned, truffet, forholdsvis, slapp, glæde, visselig, tidlig, vandret, videre, dere, glede, blikk, likesom, gaar, smaa, visse, menneske, hænder, skrek, nåar, sett, lille, særlig, mørke, Nei, nådde, ogsaa, lot, hender, ville, lange, Så, os, gik, gamle, siste, ...., Den, hvis, Hans, ind, bare, liten, disse, noget, mange, uten, gikk, men, ham, !, sine, ikke, ha, man, så, være, inn, store, denne, som, saa, den, har, ved, de, hun, Han, om, å, sig, et, over, ut, hadde, for, er, ,, en, seg, at, og, av, med, De, til, —, ., i,  Aktersnurren,  Cunningham.,  Endelig,  Enkelt,,  Feberfluene,  Fortjenesten,  Imorgen,  Jenisseiostjakene,  Jones,  Miguel,  Overfor,  Oxford-studenten,  Slike,  Syd-Amerikas,  Temperaturen,  allesammen,  buksene,  depechesal,  depesjesal,  diamanten,  forbryter-dyret,  fyrstinne,  hermetikkbokser,,  hvorledes,  ingen,  instinktivt,  kameratslig,  naturligvis,  nordlyset,  politiet,  refusert!,  representerte,  rovmorder,  sannsynligvis,  skitten,,  skjenselen.,  skyggen,  uigjennemtrængelig,,  underkokk,  unntagen,  ålendinger.,  øyensynlig,  übeslutsomme., ", "menneskelig, "motvillig, "rapport, "situasjon., #, $, %, &, ', (, (3rOnnelan6, (3re-3orvB, (3re>nneland, (3rsnnslan6, (3ulltørst., (Donomama3ks, (Ilnilisalpeterens, (lagresk!o6en., (leivar, (omhyggelig, ), *, *otøvrig, +, ,/Strømmen, -, ..., ....., ......, ......., ........, ........., ....................., ...jødinden., .1, .10, .102, .11, .163, .2, .20, .3, .6, .763, .8, .8000, .Thompson, /, /Quesada,, /^ecke?--mann, 0, 0,6, 0,7, 0,8, 0,9, 0., 00, 00., 000, 000., 0000, 0031, 0031120, 004, 005, 01, 011, 0139, 016, 0161, 02, 02610, 03, 03., 0304, 0310., 031and8-dver, 032, 033, 033., 0331, 0332, 0332., 03322, 0333, 0333., 0339, 035, 036

# %%
colls_top[:50]
# Out:
#                            0
# bedstefædre     20354.076590
# mandsperson.    20354.076590
# iLe6re          20354.076590
# paatruffet      10177.038295
# forestillingen   8198.260155
# lystne           1850.370599
# utdød            1565.698199
# elskelige        1565.698199
# paatrængende     1565.698199
# påtrengende      1272.129787
# mistenksomt      1051.058994
# koster            931.620472
# adskilte          753.854689
# tilsengs          701.864710
# etterlot          656.583116
# dragt             616.790200
# efterlot          484.620871
# fe                455.458898
# karakteristisk    433.065459
# yngre             301.406623
# utvilsomt         282.695508
# mellemrum         166.836693
# overrasket        139.411483
# saaledes          132.169329
# naadde            118.337655
# lykkelig          104.038834
# enkelte            97.387926
# saaes              96.924174
# gned               95.107426
# truffet            92.099894
# forholdsvis        89.665536
# slapp              85.935641
# glæde              72.434436
# visselig           72.434436
# tidlig             59.168827
# vandret            49.765468
# videre             46.523561
# dere               43.377038
# glede              36.024914
# blikk              34.621031
# likesom            31.902941
# gaar               31.074926
# smaa               30.792854
# visse              29.932466
# menneske           28.953167
# hænder             28.830137
# skrek              28.786026
# nåar               27.844154
# sett               26.531586
# lille              25.112911

# %%
nb.get_urnkonk('jøde',{'urns':Richterkorpus_def})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011072720002?searchText=jøde' target='_blank' style='text-decoration:none'>De sorte gribbe, Frich, Øvre Richter, 1914</a>
#                 </td>
#                 <td>gammelt arvestykke . Den gamle</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i Rue Jacob , som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007042001030?searchText=jøde' target='_blank' style='text-decoration:none'>Jorden som dreper, Frich, Øvre Richter, 1966</a>
#                 </td>
#                 <td>— Den lille</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>raser , sa han med</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072501028?searchText=jøde' target='_blank' style='text-decoration:none'>Olympieren, Frich, Øvre Richter, 1970</a>
#                 </td>
#                 <td>det ikke om man var</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, neger , indianer eller</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009042000107?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede næver, Frich, Øvre Richter, 1997</a>
#                 </td>
#                 <td>dig præparere av en anden</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i mekanik .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009042000107?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede næver, Frich, Øvre Richter, 1997</a>
#                 </td>
#                 <td>for 15000 kroner til en</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i Moabit og jeg stjal</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121008120?searchText=jøde' target='_blank' style='text-decoration:none'>Kanonernes sjel, Frich, Øvre Richter, 1915</a>
#                 </td>
#                 <td>brynene . Jeg er seiv</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, sa han barskt .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121008120?searchText=jøde' target='_blank' style='text-decoration:none'>Kanonernes sjel, Frich, Øvre Richter, 1915</a>
#                 </td>
#                 <td>. Men jeg er tysk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>paa samme maate som Maximilian</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121008120?searchText=jøde' target='_blank' style='text-decoration:none'>Kanonernes sjel, Frich, Øvre Richter, 1915</a>
#                 </td>
#                 <td>. . ! Den lille</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, som laa der og</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121008120?searchText=jøde' target='_blank' style='text-decoration:none'>Kanonernes sjel, Frich, Øvre Richter, 1915</a>
#                 </td>
#                 <td>. Vel , den lille</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>var død . Imorgen staar</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013121008120?searchText=jøde' target='_blank' style='text-decoration:none'>Kanonernes sjel, Frich, Øvre Richter, 1915</a>
#                 </td>
#                 <td>igaar sammen med den lille</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, som . . .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014072808161?searchText=jøde' target='_blank' style='text-decoration:none'>Menneskejegerne, Frich, Øvre Richter, 1967</a>
#                 </td>
#                 <td>hvor en eller annen tysk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>før krigen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012101507191?searchText=jøde' target='_blank' style='text-decoration:none'>Olympieren, Frich, Øvre Richter, 1924</a>
#                 </td>
#                 <td>ikke , om man var</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, neger , indianer eller</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112924070?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede never, Frich, Øvre Richter, 1936</a>
#                 </td>
#                 <td>dig preparere av en annen</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i mekanikk .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061906092?searchText=jøde' target='_blank' style='text-decoration:none'>Jakob Harvis, spilleren, Frich, Øvre Richter, 1969</a>
#                 </td>
#                 <td>som er kjøpt hos en</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i Rouen enn i Barclays</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061906092?searchText=jøde' target='_blank' style='text-decoration:none'>Jakob Harvis, spilleren, Frich, Øvre Richter, 1969</a>
#                 </td>
#                 <td>på Montparnasse og en klokke</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>fra St . Antoine .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012061906092?searchText=jøde' target='_blank' style='text-decoration:none'>Jakob Harvis, spilleren, Frich, Øvre Richter, 1969</a>
#                 </td>
#                 <td>det forbindelse med en manufaktur</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, som hadde kjøpt Deres</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012020104071?searchText=jøde' target='_blank' style='text-decoration:none'>Slangeblomsten fra Magdala, Frich, Øvre Richter, 1927</a>
#                 </td>
#                 <td>, haarde hænder som en</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, der øiner en chance</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015021108041?searchText=jøde' target='_blank' style='text-decoration:none'>Guldaaren, Frich, Øvre Richter, 1914</a>
#                 </td>
#                 <td>for 2000 dollars til en</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, som nu bor i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015021108041?searchText=jøde' target='_blank' style='text-decoration:none'>Guldaaren, Frich, Øvre Richter, 1914</a>
#                 </td>
#                 <td>ikke prutte som en gammel</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>. Det er chance .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012101507105?searchText=jøde' target='_blank' style='text-decoration:none'>Lucifers øie, Fr
