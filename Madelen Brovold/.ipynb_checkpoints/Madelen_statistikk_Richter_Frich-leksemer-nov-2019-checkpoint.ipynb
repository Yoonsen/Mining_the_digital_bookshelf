# %% [markdown]
# # Statistikk fra Bokhylla på _jøde_
#
# Bare hopp over den første biten til dere kommer til en neste hovedoverskrift. Deretter kan narrative følges.
#
# Kollokasjoner for Øvre Richter Frich

# %% [markdown]
# ##### Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
code_toggle()
# Out:
# <div>
#                 <style>
#                  .mybutton {
#                     background-color: #f08014;
#                     border: none;
#                     color: white;
#                     padding: 10px 16px;
#                     text-align: center;
#                     text-decoration: none;
#                     display: inline-block;
#                     font-size: 16px;
#                     margin: 4px 2px;
#                     cursor: pointer;
#                 }
#             </style>
#             <script>
#                 code_show=true;
#                 function code_toggle() {
#                  if (code_show){
#                  $('div.input').hide();
#                  } else {
#                  $('div.input').show();
#                  }
#                  code_show = !code_show
#                 }
#                 $( document ).ready(code_toggle);
#             </script>
#             <form  action="javascript:code_toggle()">
#                 <input class='mybutton' type="submit" value="Klikk for å vise/skjule kodeceller">
#             </form>
#         </div>

# %% [markdown]
# ##### Module imports

# %%
import re
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import networkx as nx
from graph_networkx_louvain import cutdown, make_collocation_graph
import pandas as pd
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Bygger korpus
#
# Korpus for Øvre Richter Frich, alle ord med 'jød' i.

# %%
words = """Hebræer Hebræeren Hebræere Hebræerne
hebræer hebræeren hebræere hebræerne
Hebreer Hebreeren Hebreere Hebreerne
hebreer hebreeren hebreere hebreerne
Israelit Israeliten Israeliter Israeliterne Israelitene
israelit israeliten israeliter israeliterne israelitene
Israelitt Israelitten Israelitter Israelitterne Israelittene
israelitt israelitten israelitter israelitterne israelittene​
Mosait Mosaiten Mosaiter Mosaiterne Mosaitene
mosait mosaiten mosaiter mosaiterne mosaitene
Mosaitt Mosaitten Mosaitter Mosaitterne Mosaittene
mosaitt mosaitten mosaitter mosaitterne mosaittene
Jødebolsjevik Jødebolsjeviken Jødebolsjeviker Jødebolsjevikerne Jødebolsjevikene
jødebolsjevik jødebolsjeviken jødebolsjeviker jødebolsjevikerne jødebolsjevikene""".split()
words = words + [x.capitalize() for x in words]
words
# Out:
# ['Hebræer',
#  'Hebræeren',
#  'Hebræere',
#  'Hebræerne',
#  'hebræer',
#  'hebræeren',
#  'hebræere',
#  'hebræerne',
#  'Hebreer',
#  'Hebreeren',
#  'Hebreere',
#  'Hebreerne',
#  'hebreer',
#  'hebreeren',
#  'hebreere',
#  'hebreerne',
#  'Israelit',
#  'Israeliten',
#  'Israeliter',
#  'Israeliterne',
#  'Israelitene',
#  'israelit',
#  'israeliten',
#  'israeliter',
#  'israeliterne',
#  'israelitene',
#  'Israelitt',
#  'Israelitten',
#  'Israelitter',
#  'Israelitterne',
#  'Israelittene',
#  'israelitt',
#  'israelitten',
#  'israelitter',
#  'israelitterne',
#  'israelittene\u200b',
#  'Mosait',
#  'Mosaiten',
#  'Mosaiter',
#  'Mosaiterne',
#  'Mosaitene',
#  'mosait',
#  'mosaiten',
#  'mosaiter',
#  'mosaiterne',
#  'mosaitene',
#  'Mosaitt',
#  'Mosaitten',
#  'Mosaitter',
#  'Mosaitterne',
#  'Mosaittene',
#  'mosaitt',
#  'mosaitten',
#  'mosaitter',
#  'mosaitterne',
#  'mosaittene',
#  'Jødebolsjevik',
#  'Jødebolsjeviken',
#  'Jødebolsjeviker',
#  'Jødebolsjevikerne',
#  'Jødebolsjevikene',
#  'jødebolsjevik',
#  'jødebolsjeviken',
#  'jødebolsjeviker',
#  'jødebolsjevikerne',
#  'jødebolsjevikene',
#  'Hebræer',
#  'Hebræeren',
#  'Hebræere',
#  'Hebræerne',
#  'Hebræer',
#  'Hebræeren',
#  'Hebræere',
#  'Hebræerne',
#  'Hebreer',
#  'Hebreeren',
#  'Hebreere',
#  'Hebreerne',
#  'Hebreer',
#  'Hebreeren',
#  'Hebreere',
#  'Hebreerne',
#  'Israelit',
#  'Israeliten',
#  'Israeliter',
#  'Israeliterne',
#  'Israelitene',
#  'Israelit',
#  'Israeliten',
#  'Israeliter',
#  'Israeliterne',
#  'Israelitene',
#  'Israelitt',
#  'Israelitten',
#  'Israelitter',
#  'Israelitterne',
#  'Israelittene',
#  'Israelitt',
#  'Israelitten',
#  'Israelitter',
#  'Israelitterne',
#  'Israelittene\u200b',
#  'Mosait',
#  'Mosaiten',
#  'Mosaiter',
#  'Mosaiterne',
#  'Mosaitene',
#  'Mosait',
#  'Mosaiten',
#  'Mosaiter',
#  'Mosaiterne',
#  'Mosaitene',
#  'Mosaitt',
#  'Mosaitten',
#  'Mosaitter',
#  'Mosaitterne',
#  'Mosaittene',
#  'Mosaitt',
#  'Mosaitten',
#  'Mosaitter',
#  'Mosaitterne',
#  'Mosaittene',
#  'Jødebolsjevik',
#  'Jødebolsjeviken',
#  'Jødebolsjeviker',
#  'Jødebolsjevikerne',
#  'Jødebolsjevikene',
#  'Jødebolsjevik',
#  'Jødebolsjeviken',
#  'Jødebolsjeviker',
#  'Jødebolsjevikerne',
#  'Jødebolsjevikene']

# %% [markdown]
# Først defineres korpuset som alle bøker forfattet av Øver Richter Frich

# %%
Richterkorpus_def = nb.get_urn({'author':'frich%richter%', 'limit':200})

# %%
Richterkorpus_def
# Out:
# [[2014021807072, 'Frich, Øvre Richter', 'De sorte gribber', 1987],
#  [2011072720002, 'Frich, Øvre Richter', 'De sorte gribbe', 1914],
#  [2007051501008, 'Frich, Øvre Richter', 'Men Rocambole var ikke død- !', 1968],
#  [2007060500019, 'Frich, Øvre Richter', 'Havets øyne', 1965],
#  [2013071208198, 'Frich, Øvre Richter', 'gyldne pest', 1913],
#  [2011121906000, 'Frich, Øvre Richter', 'Pans fløite', 1922],
#  [2007042001030, 'Frich, Øvre Richter', 'Jorden som dreper', 1966],
#  [2012011208025, 'Frich, Øvre Richter', 'Det ytterste hav', 1972],
#  [2014111108202, 'Frich, Øvre Richter', 'Nordlysets datter', 1934],
#  [2012092706010, 'Frich, Øvre Richter', 'De knyttede never', 1985],
#  [2012100907160, 'Frich, Øvre Richter', 'flyvende koffert', 1930],
#  [2015011608019, 'Frich, Øvre Richter', 'Menneskejegerne', 1935],
#  [2012062706150, 'Frich, Øvre Richter', 'Jacques Delmas forbandelse', 1926],
#  [2009042000107, 'Frich, Øvre Richter', 'De knyttede næver', 1997],
#  [2007073001051, 'Frich, Øvre Richter', 'Rottene', 1970],
#  [2016041548096, 'Frich, Øvre Richter', 'Solkongens arv', 1922],
#  [2011120208144, 'Frich, Øvre Richter', 'Gullåren', 1985],
#  [2011121412003, 'Frich, Øvre Richter', 'gyldne pest', 1914],
#  [2012101507208, 'Frich, Øvre Richter', 'Rotterne', 1925],
#  [2011112924084, 'Frich, Øvre Richter', 'De sorte gribber', 1936],
#  [2014093008020, 'Frich, Øvre Richter', 'Jorden som dræper', 1921],
#  [2007051000048, 'Frich, Øvre Richter', 'Vampyren', 1968],
#  [2007051504020, 'Frich, Øvre Richter', 'Madonnas smil', 1969],
#  [2011112924085, 'Frich, Øvre Richter', 'Kondoren', 1936],
#  [2014030308120, 'Frich, Øvre Richter', 'Morgenrødens vinger', 1921],
#  [2012101106035, 'Frich, Øvre Richter', 'Storfjellets herre', 1932],
#  [2012052204072, 'Frich, Øvre Richter', 'Journalisten og filmstjernen', 1929],
#  [2016041148006, 'Frich, Øvre Richter', 'gyldne pest', 1919],
#  [2007043000006, 'Frich, Øvre Richter', 'Jacques Delmas forbannelse', 1966],
#  [2012020104029, 'Frich, Øvre Richter', 'Vampyren', 1942],
#  [2012020104071, 'Frich, Øvre Richter', 'Slangeblomsten fra Magdala', 1927],
#  [2015043007533, 'Frich, Øvre Richter', 'Saksofonkongen', 1930],
#  [2015111007514, 'Frich, Øvre Richter', 'De knyttede never', 1965],
#  [2011041820016, 'Frich, Øvre Richter', 'røde taake', 1914],
#  [2014120208274, 'Frich, Øvre Richter', 'Lille-Jonas Fjeld', 1918],
#  [2012100106015, 'Frich, Øvre Richter', 'Havfruens sønn', 1933],
#  [2007051500071, 'Frich, Øvre Richter', 'De udødelige dverger', 1967],
#  [2014072808161, 'Frich, Øvre Richter', 'Menneskejegerne', 1967],
#  [2007052104057, 'Frich, Øvre Richter', 'Lille Jonas Fjeld', 1967],
#  [2015070708105, 'Frich, Øvre Richter', 'Nordlysets datter', 1967],
#  [2016091648051, 'Frich, Øvre Richter', 'gylne pest', 1987],
#  [2015110507060, 'Frich, Øvre Richter', 'Hammerslaget', 1967],
#  [2011112924074, 'Frich, Øvre Richter', 'I sølvlandets natt', 1937],
#  [2009072801081, 'Frich, Øvre Richter', 'To mann på flåten', 1942],
#  [2012070405046, 'Frich, Øvre Richter', 'De fædrelandsløses ø', 1927],
#  [2015020608001, 'Frich, Øvre Richter', 'Flyvefisken', 1914],
#  [2014042906167, 'Frich, Øvre Richter', 'Kondoren', 1985],
#  [2011112924083, 'Frich, Øvre Richter', 'gylne pest', 1937],
#  [2013040208127, 'Frich, Øvre Richter', 'Havets øine', 1937],
#  [2008020104002, 'Frich, Øvre Richter', 'De knyttede never', 1993],
#  [2013080208078, 'Frich, Øvre Richter', 'Kaperens klør', 1915],
#  [2011071408154, 'Frich, Øvre Richter', 'Boken om tobakk', 1934],
#  [2011112924073, 'Frich, Øvre Richter', 'Gullåren', 1936],
#  [2012101507191, 'Frich, Øvre Richter', 'Olympieren', 1924],
#  [2012110807097, 'Frich, Øvre Richter', 'Men Rocambole var ikke død- !', 1942],
#  [2011071408111, 'Frich, Øvre Richter', 'gylne pest', 1965],
#  [2011112924070, 'Frich, Øvre Richter', 'De knyttede never', 1936],
#  [2006120700113, 'Frich, Øvre Richter', 'Madonnas smil', 1925],
#  [2016031408040, 'Frich, Øvre Richter', 'De tause barn fra Ural', 1938],
#  [2014051908139, 'Frich, Øvre Richter', 'røde taake', 1919],
#  [2012100907156, 'Frich, Øvre Richter', 'Det yttersta havet', 1921],
#  [2012062105029, 'Frich, Øvre Richter', 'Bandittenes oppmarsj', 1969],
#  [2016010807587,
#   'Frich, Øvre Richter',
#   'De knyttede never ; Kondoren ; Gullåren',
#   1993],
#  [2013011708026, 'Frich, Øvre Richter', 'Lucifers øye', 1966],
#  [2012101507230, 'Frich, Øvre Richter', 'I polarnattens favn', 1920],
#  [2011102508121, 'Frich, Øvre Richter', 'Solkongens arv', 1969],
#  [2012062106081, 'Frich, Øvre Richter', 'Gullåren', 1965],
#  [2012061906092, 'Frich, Øvre Richter', 'Jakob Harvis, spilleren', 1969],
#  [2011120808017, 'Frich, Øvre Richter', 'Kondoren', 1912],
#  [2013030608230, 'Frich, Øvre Richter', 'Hyænerne', 1920],
#  [2007052904004, 'Frich, Øvre Richter', 'Slangeblomsten fra Magdala', 1967],
#  [2011112924071, 'Frich, Øvre Richter', 'røde tåke', 1937],
#  [2011120608067, 'Frich, Øvre Richter', 'Kondoren', 1954],
#  [2011112924086, 'Frich, Øvre Richter', 'Donna Francesca', 1937],
#  [2012101507105, 'Frich, Øvre Richter', 'Lucifers øie', 1920],
#  [2014021807201, 'Frich, Øvre Richter', 'I polarnattens favn', 1969],
#  [2007041901016, 'Frich, Øvre Richter', 'Pans fløyte', 1966],
#  [2007100304042,
#   'Frich, Øvre Richter',
#   'De udødelige dverge ; Lille Jonas Fjeld ; Storfjellets herre',
#   1991],
#  [2011112924075, 'Frich, Øvre Richter', 'Flyvefisken', 1937],
#  [2012100106016, 'Frich, Øvre Richter', 'Halvkunstnere', 1925],
#  [2013121008120, 'Frich, Øvre Richter', 'Kanonernes sjel', 1915],
#  [2016012129005, 'Frich, Øvre Richter', 'I polarnattens favn', 1912],
#  [2015012708287, 'Frich, Øvre Richter', 'De knyttede never', 1953],
#  [2015110307511, 'Frich, Øvre Richter', 'røde tåke', 1965],
#  [2008052100031, 'Frich, Øvre Richter', 'Flyvefisken', 1965],
#  [2014111808017, 'Frich, Øvre Richter', '2 x 3', 1938],
#  [2007080200086, 'Frich, Øvre Richter', 'Boken om tobakk', 1985],
#  [2007080701044, 'Frich, Øvre Richter', 'De fedrelandsløses øy', 1970],
#  [2007072501028, 'Frich, Øvre Richter', 'Olympieren', 1970],
#  [2013012108092, 'Frich, Øvre Richter', 'Vampyren', 1930],
#  [2015110307522, 'Frich, Øvre Richter', 'Donna Francesca', 1965],
#  [2007081712003, 'Frich, Øvre Richter', 'Det yderste hav', 1921],
#  [2013081508144, 'Frich, Øvre Richter', 'De sorte gribber', 1965],
#  [2013110808042, 'Frich, Øvre Richter', 'Storfjellets herre', 1967],
#  [2015110507025, 'Frich, Øvre Richter', 'I sølvlandets natt', 1965],
#  [2012101908038, 'Frich, Øvre Richter', 'Flyvefisken', 1988],
#  [2015021108041, 'Frich, Øvre Richter', 'Guldaaren', 1914]]

# %% [markdown]
# Dernest lager vi to objekt, først et korpus, så en aggregert versjon

# %%
corpus = nb.get_corpus_text([x[0] for x in Richterkorpus_def], top=0, cutoff=0)

# %%
aggs = nb.frame(corpus.sum(axis=1), 0)

# %% [markdown]
# Korpuset representeres som en dokument-term-matrise, der hver bok er en kolonne, med frekvensinfo for ordene. Her en liten bit.

# %%
corpus.sort_values(by=corpus.columns[0], ascending=False)[:10]
# Out:
#      2014021807072  2011072720002  2007051501008  2007060500019  \
# .           2243.0         3405.0         3598.0         3133.0
# ,           1159.0         1699.0         2289.0         1185.0
# og           811.0          818.0         1014.0          347.0
# i            624.0          611.0         1158.0          920.0
# en           581.0          588.0         1359.0          767.0
# som          473.0          432.0          521.0          432.0
# den          452.0          450.0          640.0          468.0
# det          408.0          374.0          797.0          545.0
# med          382.0          382.0          498.0          306.0
# er           369.0          377.0          661.0          407.0
#
#      2013071208198  2011121906000  2007042001030  2012011208025  \
# .           3327.0         3819.0         2651.0         2510.0
# ,           1911.0         2813.0         2041.0         1820.0
# og           899.0         1419.0         1022.0         1045.0
# i            690.0         1061.0          885.0          758.0
# en           734.0         1077.0          852.0          813.0
# som          510.0          862.0          462.0          806.0
# den          492.0          728.0          469.0          623.0
# det          451.0          641.0          581.0          644.0
# med          391.0          524.0          351.0          491.0
# er           448.0          504.0          358.0          339.0
#
#      2014111108202  2012092706010  ...  2007080701044  2007072501028  \
# .           2630.0         1960.0  ...         3599.0         3368.0
# ,           1426.0         1155.0  ...         2568.0         2540.0
# og          1195.0          798.0  ...         1430.0         1609.0
# i            915.0          552.0  ...         1180.0         1104.0
# en           866.0          520.0  ...         1174.0          995.0
# som          694.0          399.0  ...         1100.0          865.0
# den          753.0          374.0  ...          902.0          663.0
# det          721.0          353.0  ...         1057.0          824.0
# med          510.0          312.0  ...          612.0          611.0
# er           443.0          336.0  ...          730.0          545.0
#
#      2013012108092  2015110307522  2007081712003  2013081508144  \
# .           4400.0         3400.0         2739.0         2322.0
# ,           2294.0         1749.0         2224.0         1165.0
# og          1123.0         1389.0         1038.0          810.0
# i           1024.0         1019.0          742.0          633.0
# en          1050.0          874.0          813.0          582.0
# som          699.0          963.0          699.0          474.0
# den          764.0          740.0          625.0          452.0
# det          702.0          765.0          552.0          408.0
# med          608.0          525.0          486.0          381.0
# er           616.0          473.0          333.0          369.0
#
#      2013110808042  2015110507025  2012101908038  2015021108041
# .           3115.0         2895.0         3625.0         3347.0
# ,           2334.0         1052.0         1334.0         1731.0
# og          1240.0         1045.0         1178.0          833.0
# i           1075.0          827.0         1012.0          656.0
# en          1068.0          766.0          880.0          626.0
# som          889.0          668.0          814.0          408.0
# den          785.0          636.0          697.0          451.0
# det          849.0          569.0          772.0          373.0
# med          551.0          400.0          444.0          299.0
# er           523.0          484.0          524.0          364.0
#
# [10 rows x 97 columns]

# %% [markdown]
# ## Listen
#
# Fra ordene i korpuseet konstrueres en  liste over alle ord som matcher en av ordene i listen. Ikke alle vil være relevant, men det er en kort liste som gås gjennom manuelt, se neste bolk.

# %% [markdown]
# ## Frekvenser for jødeord
#
#
# Hvor ofte forekommer ordene i listen over i Frichs forfatterskap? For helt nøyaktige tall må kanskje korpuset bearbeides litt med hensyn til duplikater. Noen tekster kan opptre flere ganger.

# %%
aggs.transpose()[[w for w in words if w in aggs.index]].transpose()[:20]
# Out:
#               0
# hebræer     7.0
# hebreer     3.0
# hebreerne   1.0
# israelit    2.0
# israeliter  4.0
# israelitt   5.0

# %%
new_words = list(aggs.transpose()[[w for w in words if w in aggs.index]].transpose()[:20].index)

# %% [markdown]
# # Ord og bøker
#
# Kobling til bøker

# %%
corpus_dict = corpus.transpose().fillna(0)
books = dict()
for w in new_words:
    books[w] = nb.frame(nb.metadata(list(corpus_dict[w][corpus_dict[w] > 0].index)),'urn f år tittel forlag språk ov'.split())

# %% [markdown]
# ## Koblinger mellom jødeord og frekvenser

# %%
print(corpus_dict[new_words].sum(axis=0))
# Out:
# hebræer       7.0
# hebreer       3.0
# hebreerne     1.0
# israelit      2.0
# israeliter    4.0
# israelitt     5.0
# dtype: float64

# %% [markdown]
# # Frekvenser fra dokument-term-matrisen
#
# Matrisen viser hvilke ord som forekommer i hvilke bøker, tallet viser til frekvensen.

# %%
for i in corpus_dict.index:
    corpus_dict.rename(index= {i:  str(i) + '_' + nb.metadata(i)[0][3]}, inplace=True)

# %%
nb.heatmap(corpus_dict[new_words])
# Out:
# <style  type="text/css" >
#     #T_50cf2428_0923_11ea_8566_000acd2bfab2row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row4_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row5_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row5_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row5_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row6_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row6_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row7_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row7_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row7_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row8_col0 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row8_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row8_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row9_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row9_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row9_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_50cf2428_0923_11ea_8566_000acd2bfab2row9_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
