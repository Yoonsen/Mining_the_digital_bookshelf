# %% [markdown]
# # Statistikk fra Bokhylla på _jøde_
#
# Bare hopp over den første biten til dere kommer til en neste hovedoverskrift. Deretter kan narrative følges.
#
# Kollokasjoner for Øvre Richter Frich

# %%
from dhlab.module_update import update, css

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ##### Module imports

# %%
import dhlab.nbtext as nb
import dhlab.graph_networkx_louvain as gnl
import networkx as nx
from dhlab.graph_networkx_louvain import cutdown, make_collocation_graph
import pandas as pd
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Bygg korpus og analysér
#
# Hent URN-er fra tekst eller metadata. URNene representer korpuset, eller en definisjon av korpuset. Korpuset bygges med ordene som metadata lagt inn i variabelen `words`. Korpusets URNer ligger i variabelen `korpusår`.

# %%
words = """Hebræer Hebræeren Hebræere Hebræerne
hebræer hebræeren hebræere hebræerne
Hebreer Hebreeren Hebreere Hebreerne
hebreer hebreeren hebreere hebreerne
Israelit Israeliten Israeliter Israeliterne Israelitene
israelit israeliten israeliter israeliterne israelitene
Israelitt Israelitten Israelitter Israelitterne Israelittene
israelitt israelitten israelitter israelitterne israelittene​
Mosait Mosaiten Mosaiter Mosaiterne Mosaitene
mosait mosaiten mosaiter mosaiterne mosaitene
Mosaitt Mosaitten Mosaitter Mosaitterne Mosaittene
mosaitt mosaitten mosaitter mosaitterne mosaittene
Jødebolsjevik Jødebolsjeviken Jødebolsjeviker Jødebolsjevikerne Jødebolsjevikene
jødebolsjevik jødebolsjeviken jødebolsjeviker jødebolsjevikerne jødebolsjevikene""".split()
words = words + [x.capitalize() for x in words]

# %%
Richterkorpus_def = nb.get_urn({'author':'%frich%richter%', 'limit':200})
len(Richterkorpus_def)
# Out:
# 97

# %%
aggs = nb.get_aggregated_corpus(Richterkorpus_def)

# %% [markdown]
# ## Kollokasjoner
#
# Her kjøres kollokasjoner for ord med forskjellige krav til frekvens.

# %% [markdown]
# ### Kollokasjoner for n=5
#
# For å være med i kollokasjonene kreves at ordet forekommer minst 6 ganger i hele korpuset

# %%
colls = nb.urn_coll_words(words, urns=Richterkorpus_def )

# %%
nb.normalize_corpus_dataframe(colls)
nb.normalize_corpus_dataframe(aggs)

# %%
3/len(aggs)

# %%
colls_top = pd.DataFrame(colls[0]**1.01/(aggs[aggs[0] > 0.00000016][0])).sort_values(by=0, ascending=False)

# %%
print(', '.join(list(colls_top.index[:250])))

# %%
colls_top[:50]
# Out:
#                              0
# forkorter          1980.470662
# møblet             1980.470662
# rypesekk           1980.470662
# gullbelessede      1974.781391
# guldbelæssede      1974.781391
# bedaare            1974.781391
# allvidenhet        1966.790552
# suffragetterne     1966.790552
# Suffragia          1966.790552
# alvidenhet         1966.790552
# medvirker          1966.790552
# pengesaker         1966.790552
# transfusion        1953.204938
# mamselle           1953.204938
# orkorter           1953.204938
# slagterfamilie     1953.204938
# Handelsmanden      1953.204938
# literære           1953.204938
# Goliaths           1953.204938
# ordeuens           1953.204938
# hollendere,        1953.204938
# transfusjon        1953.204938
# rakker             1953.204938
# trengende          1953.204938
# reisepass          1953.204938
# utspringet         1953.204938
# kinesaren          1953.204938
# gatelarmen.        1953.204938
# sprogforvirringen  1953.204938
# jesuitter-         1953.204938
# naturligvis,       1953.204938
# språkforvirringen  1953.204938
# interssant         1953.204938
# reisepas           1953.204938
# beskylder          1654.079074
# gjennemlett        1584.376530
# fniste             1491.387811
# bedåre             1481.086043
# gojim              1481.086043
# måpende            1102.719383
# Niggeren            992.447445
# yngler              976.602469
# begravel-           976.602469
# loi                 976.602469
# anholdt             976.602469
# belønning.          976.602469
# grækere             786.716221
# ordenens            720.171150
# Rosenbaum           661.631630
# krodde              660.156887

# %%
nb.get_urnkonk('jøde',{'urns':Richterkorpus_def})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013011708026?searchText=jøde' target='_blank' style='text-decoration:none'>Lucifers øye, Frich, Øvre Richter, 1966</a>
#                 </td>
#                 <td>, der lignet en polsk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>eller kanskje var det ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014021807072?searchText=jøde' target='_blank' style='text-decoration:none'>De sorte gribber, Frich, Øvre Richter, 1987</a>
#                 </td>
#                 <td>gammelt arvestykke . Den gamle</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i Rue Jacob som solgte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012101507208?searchText=jøde' target='_blank' style='text-decoration:none'>Rotterne, Frich, Øvre Richter, 1925</a>
#                 </td>
#                 <td>» , den entrepenante estlandske</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, hadde adskillig bryderi —</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112924085?searchText=jøde' target='_blank' style='text-decoration:none'>Kondoren, Frich, Øvre Richter, 1936</a>
#                 </td>
#                 <td>anvist losji hos en portugisisk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>. Det var en liten</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007081712003?searchText=jøde' target='_blank' style='text-decoration:none'>Det yderste hav, Frich, Øvre Richter, 1921</a>
#                 </td>
#                 <td>ophøiede ro som hin gamle</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>hadde , da han saa</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012101507105?searchText=jøde' target='_blank' style='text-decoration:none'>Lucifers øie, Frich, Øvre Richter, 1920</a>
#                 </td>
#                 <td>, der lignet en polsk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>eller maaske var det ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112924084?searchText=jøde' target='_blank' style='text-decoration:none'>De sorte gribber, Frich, Øvre Richter, 1936</a>
#                 </td>
#                 <td>gammelt arvestykke . Den gamle</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i Rue Jacob som solgte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007073001051?searchText=jøde' target='_blank' style='text-decoration:none'>Rottene, Frich, Øvre Richter, 1970</a>
#                 </td>
#                 <td>» , den entrepenante estlandske</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, hadde atskillig bryderi —</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012011208025?searchText=jøde' target='_blank' style='text-decoration:none'>Det ytterste hav, Frich, Øvre Richter, 1972</a>
#                 </td>
#                 <td>opphøyde ro som hin gamle</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>hadde , da han så</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011072720002?searchText=jøde' target='_blank' style='text-decoration:none'>De sorte gribbe, Frich, Øvre Richter, 1914</a>
#                 </td>
#                 <td>gammelt arvestykke . Den gamle</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i Rue Jacob , som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010807587?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede never ; Kondoren ; Gullåren, Frich, Øvre Richter, 1993</a>
#                 </td>
#                 <td>deg preparere av en annen</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i mekanikk .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010807587?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede never ; Kondoren ; Gullåren, Frich, Øvre Richter, 1993</a>
#                 </td>
#                 <td>anvist losji hos en portugisisk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>. Det var en liten</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010807587?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede never ; Kondoren ; Gullåren, Frich, Øvre Richter, 1993</a>
#                 </td>
#                 <td>2 000 dollars til en</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, som nu bor i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010807587?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede never ; Kondoren ; Gullåren, Frich, Øvre Richter, 1993</a>
#                 </td>
#                 <td>ikke prutte som en gammel</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>. Det er chanse .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014072808161?searchText=jøde' target='_blank' style='text-decoration:none'>Menneskejegerne, Frich, Øvre Richter, 1967</a>
#                 </td>
#                 <td>hvor en eller annen tysk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>før krigen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007072501028?searchText=jøde' target='_blank' style='text-decoration:none'>Olympieren, Frich, Øvre Richter, 1970</a>
#                 </td>
#                 <td>det ikke om man var</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>, neger , indianer eller</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015011608019?searchText=jøde' target='_blank' style='text-decoration:none'>Menneskejegerne, Frich, Øvre Richter, 1935</a>
#                 </td>
#                 <td>hvor en eller annen tysk</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>før krigen hadde laget pølser</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015111007514?searchText=jøde' target='_blank' style='text-decoration:none'>De knyttede never, Frich, Øvre Richter, 1965</a>
#                 </td>
#                 <td>deg reparere av en annen</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>i mekanikk .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2011112924086?searchText=jøde' target='_blank' style='text-decoration:none'>Donna Francesca, Frich, Øvre Richter, 1937</a>
#                 </td>
#                 <td>noen annen . Den lille</td>
#                 <td>jøde</td>
#                 <td style='text-align:left'>smilte uforstående , men bukket</td>
#             </tr>
# <tr>
#                 <td>

# %%
collett = nb.get_urn({'author':'Coll%cam%', 'year':1850, 'next':20})
collett
# Out:
# [[2006111400028, 'Collett, Camilla', 'I de lange Nætter', 1863],
#  [2009081403009, 'Collett, Camilla', 'Fortællinger', 1861],
#  [2009072212002, 'Collett, Camilla', 'undersøisk Parlament', 1863],
#  [2009072212001, 'Collett, Camilla', 'Amtmannens döttrar', 1863],
#  [2013100708166, 'Collett, Camilla', 'Sidste Blade', 1868],
#  [2009072912002, 'Collett, Camilla', 'Under ljusa dagar', 1866],
#  [2009072812001, 'Collett, Camilla', 'Under långa nätter', 1866],
#  [2009072712002, 'Collett, Camilla', 'Berättelser', 1865],
#  [2009072813006, 'Collett, Camilla', '2 April 1860', 1860],
#  [2009072112001, 'Collett, Camilla', 'Amtmandens Døttre', 1860]]

# %%
mand = nb.urn_coll('Manden',urns=collett).sort_values(by=0, ascending=False)

# %%
agg = nb.get_aggregated_corpus(collett)

# %%
import pandas as pd

# %%
pd.DataFrame(mand[0]/agg[agg[0] >5][0]).sort_values(by=0, ascending=False)
# Out:
#                      0
# gal           0.250000
# klog          0.166667
# Konen         0.166667
# kjsbt         0.166667
# staaende      0.142857
# bsd           0.142857
# osv.          0.125000
# Eventyret     0.111111
# byder         0.111111
# Aa            0.105263
# Indre         0.100000
# vred          0.100000
# Antal         0.090909
# tenke         0.090909
# forsikrede    0.083333
# svaret        0.076923
# naaede        0.066667
# fremfor       0.058824
# Familien      0.050000
# indenfor      0.047619
# Stedet        0.034483
# halv          0.033333
# Er            0.032787
# spurgte       0.025641
# levende       0.025641
# sta           0.025000
# traf          0.021277
# borte         0.021277
# Slags         0.020000
# Dine          0.019608
# ...                ...
# øitte              NaN
# øm                 NaN
# øn                 NaN
# øor                NaN
# øorban             NaN
# øore               NaN
# øorfor             NaN
# øort               NaN
# ør                 NaN
# øreb               NaN
# øren               NaN
# øttre              NaN
# øære               NaN
# øæret              NaN
# üb                 NaN
# übarmhjertig       NaN
# übbreb             NaN
# übbrøb             NaN
# übe                NaN
# übegribelig        NaN
# üben               NaN
# übenfor            NaN
# übeskrivelig       NaN
# übetinget          NaN
# übfatte            NaN
# übg                NaN
# —                  NaN
# „                  NaN
# •                  NaN
# ■                  NaN
#
# [7887 rows x 1 columns]

# %%
korp = nb.get_urn({'words':'spise'.split(), 'subject':'jakt', 'ddk':'799%'})

# %%
korp
# Out:
# [[2010052603001, 'Haga, Olav', 'Harejakt', 1995],
#  [2007112201026, 'Ravn, Thorvald L.', 'Skogsfugljakt - på min måte', 1993],
#  [2011052605059, 'Halvorsen, Tor S.', 'Alaska', 1993],
#  [2015052808067, 'Kjesbu, Johannes', 'På jakt', 1993],
#  [2010113006060, 'Kirkemo, Ole', 'Rypeskratt og laksesprang', 1991],
#  [2011110908081, 'Weitemeyer, Aage', 'Jakt med rifle', 1971],
#  [2007043004063, 'Aramilev, Ivan', 'Taiga', 1960],
#  [2007072301079, '', 'Jegerens oppslagsbok', 1970],
#  [2010112508040, 'Lier-Hansen, Stein', 'Jegerprøveboka', 1991],
#  [2010072903029, '', 'Jakt, fiske, friluftsliv', 1985]]
