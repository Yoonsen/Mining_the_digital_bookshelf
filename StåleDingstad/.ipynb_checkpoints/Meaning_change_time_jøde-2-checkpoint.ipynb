# %% [markdown]
# # Notebook for meaning and variation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import json
import requests
from IPython.display import HTML
import seaborn as sns
from scipy.spatial.distance import cosine

sns.set_style('white')
# %matplotlib inline

# %% [markdown]
# ## The next cell...
#
# ...contains a reference to databases used for calibrating data. Download and unpack those and place them somewhere on your disk. Change the content of the variables __book_db__ and __paper_db__ that are defined in that cell, so that the value of each variable is a path to one of these databases. Follow the pattern given in the cell (on Unix the path will typically start with /home/..., on windows c:/Users/..., on Mac ...)
#
# Books:
# http://www.nb.no/sbfil/ngram/20150604_uni-bok-sqlite.tar.gz
#
# Newspapers:
# http://www.nb.no/sbfil/ngram/20150604_uni-avis-sqlite.tar.gz

# %%
book_db =  "C:/Users/larsj/Documents/dev/unigram-one-row.db"
paper_db = "C:/Users/larsj/Downloads/avis-unigram-one-row.db"

# %% [markdown]
#  ## Program code (scroll past it ...)

# %%
def get_konk(word, params=dict(), kind='html'):
    import requests
    import pandas as pd
    
    para = params
    para['word']= word

    corpus = 'bok'
    if 'corpus' in para:
        corpus = para['corpus']
    else:
        para['corpus'] = corpus
        
    r = requests.get('https://api.nb.no/ngram/konk', params=para)
    if kind=='html':
        rows = ""
        if corpus == 'bok':
            for x in r.json():
                rows += """<tr>
                <td>
                    <a href='{urn}' target='_'>{urnredux}</a>
                    <td>{b}</td>
                    <td>{w}</td>
                    <td style='text-align:left'>{a}</td>
                    </tr>\n""".format(urn=x['urn'], 
                                      urnredux=','.join([x['author'], x['title'], str(x['year'])]),
                                      b=x['before'],
                                      w=x['word'],
                                      a=x['after']
                                     )
            res = "<table>{rows}</table>".format(rows=rows)   
        else:
            #print(r.json())
            for x in r.json():
                rows += """<tr>
                <td>
                    <a href='{urn}' target='_'>{urnredux}</a>
                    <td>{b}</td>
                    <td>{w}</td>
                    <td style='text-align:left'>{a}</td>
                    </tr>\n""".format(urn=x['urn'], 
                                      urnredux=x['urn'],
                                      b=x['before'],
                                      w=x['word'],
                                      a=x['after']
                                     )
            res = "<table>{rows}</table>".format(rows=rows)   
    elif kind == 'json':
        res = r.json()
    else:
        try:
            if corpus == 'bok':
                res = pd.DataFrame(r.json())
                res = res[['urn','author','title','year','before','word','after']]
            else:
                res = pd.DataFrame(r.json())
                res = res[['urn','before','word','after']]
            
        except:
            res= pd.DataFrame()
        #r = r.style.set_properties(subset=['after'],**{'text-align':'left'})
    return res

def konk_to_html(jsonkonk):
    rows = ""
    for x in jsonkonk:
        rows += "<tr><td><a href='{urn}' target='_'>{urnredux}</a><td>{b}</td><td>{w}</td><td style='text-align:left'>{a}</td></tr>\n".format(urn=x['urn'],
                                                                                                          urnredux=x['urn'],
                                                                                                          b=x['before'],
                                                                                                      w=x['word'],
                                                                                                          a=x['after'])
    res = "<table>{rows}</table>".format(rows=rows)   
    return res

def get_urnkonk(word, params=dict()):
    import requests
    import pandas as pd
    
    para = params
    para['word']= word
    r = requests.post('https://api.nb.no/ngram/urnkonk', json=para)
    r = pd.DataFrame(r.json())
    r = r[['urn','before','word','after']]
    #r = r.style.set_properties(subset=['after'],**{'text-align':'left'})
    return r
    
def get_ngram(word, params=dict()):
    import requests
    import pandas as pd
    
    para = params
    para['word']= word
    r = requests.get('https://api.nb.no/ngram/ngram', params=para)
    r = pd.DataFrame.from_dict(r.json(), orient='index').sort_index()
    #r.columns = [word]
    return r

def conc_counts_tot(mns):
    mc = dict()
    for key in mns:
        lkey = '{f}-{t}'.format(f=key[0],t=key[1])
        mc[lkey] = Counter()
        if not(mns[key].empty):
            for x in mns[key]['after']:
                if x != None:
                    mc[lkey].update(x.split())
            for x in mns[key]['before']:
                if x != None:
                    mc[lkey].update(x.split())        
    return mc

def conc_counts_rel(mns, corpus='bok'):
    mc = dict()
    for key in mns:
        lkey = '{f}-{t}'.format(f=key[0],t=key[1])
        mc[lkey] = Counter()

        if not(mns[key].empty):
            for x in mns[key]['after']:
                if x != None:
                    mc[lkey].update(x.split())
            for x in mns[key]['before']:
                if x != None:
                    mc[lkey].update(x.split())  
            db = paper_db
            if corpus == 'bok':
                db = book_db
            mc[lkey] = relativize(mc[lkey], unigram=db)
    return mc

def relativize(c_obj, gtot=20000000000, unigram = paper_db):
    import sqlite3
    from collections import Counter
    import numpy as np
    
    res = Counter()
    smalltot = sum(c_obj.values())
    with sqlite3.connect(unigram) as con:
        cur = con.cursor()
        for key in c_obj:
            val = cur.execute("select freq from unigram where first=?", (key,)).fetchall()
            if val != []:
                res[key] =np.log2(c_obj[key]) * np.log2((c_obj[key]/val[0][0])*(gtot/smalltot))
    return res

def plotrelative(ng1, ng2, period=(1850, 2005), window=2, figsize=(15,8), ymin=0, legend=False):
    import matplotlib.pyplot as plt
      
    (ng1/ng2).loc[str(period[0]):str(period[1])].rolling(window, win_type='triang').mean().plot(legend=legend, figsize=figsize);
    fymin, fymax = plt.ylim()
    plt.ylim(ymin, fymax)
    return

def heatmap(df, color='green'):
    return df.fillna(0).style.background_gradient(cmap=sns.light_palette(color, as_cmap=True))
    
def cosines(fotodf):
    cosfoto = Counter()
    done = []
    for x in fotodf.columns:
        done.append(x)
        for y in fotodf.columns:
            if y not in done:
                cosfoto[(x,y)] = (1 - cosine(fotodf[x], fotodf[y]))
    return cosfoto.most_common()            
    
def periods(p_start, p_end, step):
    årstall = list(range(p_start, p_end, step))
    ypairs = []
    for i in range(len(årstall) - 1):
        ypairs.append((årstall[i], årstall[i+1]))
    return ypairs
    
def barplot(df):
    df.fillna(0).plot(kind='bar',figsize=(15,8), color= sns.hls_palette(len(df), l=.4, s=.9));
    return 

def dewey_dist(word):
    res = dict()
    for i in range(10):
        dta = get_ngram(word, params={'corpus':'bok','ddk':i}).sum()
        res[str(i*100)] = dta
    return res

def js_delta(js1, js2):
    # Arguments as json, output a dataframe
    return pd.DataFrame.from_dict(js1, orient='index')/pd.DataFrame.from_dict(js2, orient='index')

# %%
def analyse_konk( word, subset, periods, params):
    #para_totals = totals(periods, params)
    embed = dict()
    for w in subset:
        embed[w] = get_ngram(w, params=params)
    counts = dict()
    for w in embed:
        period_counts = dict()
        for p in periods:
            period_counts[(p[0],p[1])] = embed[w].loc[str(p[0]):str(p[1])].sum()
        counts[w] = period_counts
#    for (yf, yt) in periods:
#        mns[(yf, yt)] = get_konk(word, kind='', params = params)
    return counts

def totals(periods, params):
    words = 'i og . ,'.split()
    totals = dict()
    for w in words:
        totals[w] = get_ngram(w, params=params)
    counts = dict()
    for w in totals:
        period_counts = dict()
        for p in periods:
            period_counts[(p[0],p[1])] = totals[w].loc[str(p[0]):str(p[1])].sum()
        counts[w] = period_counts
    return pd.DataFrame(pd.DataFrame(counts).sum(axis=1)*7)

def totals2(periods, params):
    words = 'i og . ,'.split()
    year_tot = total_year(params)
    counts = dict()
    period_counts = dict()
    for p in periods:
        period_counts[(p[0],p[1])] = year_tot.loc[str(p[0]):str(p[1])].sum()
    return pd.DataFrame.from_dict(period_counts,orient='index')

def total_year(params):
    words = 'i og . ,'.split()
    wcount = dict()
    for w in words:
        wcount[w] = get_ngram(w, params=params)
    return (((wcount['.']+wcount['og']).fillna(0) + wcount[',']).fillna(0) + wcount['i'])*6
    
total_avis = total_year({'corpus':'avis'})

def rel_word (word, params, relativ=total_avis):
    """Computes relative frequency based on counts in total_counts which must be present"""
    w = get_ngram(word, params)
    return w/relativ

# %%
def conc_count(konk_jsonarray, mode='relative'):
    """Concordances contain attributes {word: after: before:}, with mode relative, relative counts are returned"""
    counts = Counter()
    for konk in konk_jsonarray:
        counts.update(konk['before'].split())
        counts.update(konk['after'].split())
    if mode == 'relative':
        totals = sum(counts.values())
        for x in counts:
            counts[x] = counts[x]/totals
    return counts

# %%
import numpy as np

def check_words(words, konkcount, params, period, comparo):
    score = Counter()
    normalize = comparo.loc[period[0]:period[1]].sum()
    for w in words:
        w_data = get_ngram(w, params)
        w_data_sum = w_data.loc[period[0]:period[1]].sum()
        w_period = w_data_sum/normalize
        score[w] = np.log2(konkcount[w]/w_period)
    return score

# %%
def check_words2(konkordans, words):
    return check_words(words, konkordans, {'corpus':'avis'},('1918','1940'), total_avis)

# %%
def show_gruppe(g):
    return pd.DataFrame(g).transpose().sort_values(by=0, ascending=False)

# %%
arbeid = rel_word('arbeid',{'corpus':'avis'})

# %%
total_avis
# Out:
#                0
# 1763       16344
# 1764       99540
# 1765       22482
# 1766       94800
# 1767      327804
# 1768      388920
# 1769      372024
# 1770      371382
# 1771      379098
# 1772      421392
# 1773      410112
# 1774      399438
# 1775      398934
# 1776      419058
# 1777      427518
# 1778      398172
# 1779      284322
# 1780      303120
# 1781      530934
# 1782      510192
# 1783      438948
# 1784      643164
# 1785      676272
# 1786      660732
# 1787      667032
# 1788      643104
# 1789      576198
# 1790      559494
# 1791      578592
# 1792      614448
# ...          ...
# 1985   267388674
# 1986   298423524
# 1987   316704192
# 1988   318743202
# 1989   306109308
# 1990   517532364
# 1991   527486976
# 1992   526113996
# 1993   528512892
# 1994   529558788
# 1995   542653992
# 1996   531115194
# 1997   555051696
# 1998   537713724
# 1999   476160102
# 2000   454084944
# 2001   456941256
# 2002   387884352
# 2003   386423190
# 2004   340940376
# 2005   301435470
# 2006   272436390
# 2007   219990600
# 2008  1158798990
# 2009  1085103780
# 2010   934669272
# 2011   859934658
# 2012   251731680
# 2013   176870478
# 2014    58440918
#
# [252 rows x 1 columns]

# %%
arbeid.loc['1918':'1940'].rolling(window=3).mean().plot(figsize=(15,5))

# %% [markdown]
# ## Examine a word
#
# Fill inn a value for corpus and test word

# %%
jødedata = """Jøde: jøde, jøder, jøden, jødene, jødisk, jødiske, jødar, jødane, jødedom, jødedommen
Jødinne: jødinne, jødinnen, jødinnene, jødinner, jødinna
Jødeproblemet: jødeproblem, jødeproblemet, jødeproblemene, jødespørsmål, jødespørsmålet, jødespørsmålene, jødefare, jødefaren, jødefarene, jødefarer
Jødeforfølgelse: jødeforfølgelse, jødeforfølgelsen, jødeforfølgelser, jødeforfølgelsene
Antijødisk: antijødisk, antijødiske, anti-jødisk, anti-jødiske 
Jødekapital: jødekapital, jødekapitalen, jødekapitalist, jødekapitalistene, jødekapitalister
Jødebolsjevik: jødebolsjevik, jødebolsjevikene, jødebolsjeviken, jødebolsjeviker, bolsjevikjøde, bolsjevikjøder, bolsjevikjødene, bolsjevikjøden, bolsjevikjødar, bolsjevikjødane
Jødehat: jødehat, jødehatet, jødehater, jødehateren, jødehaterne, jødefiendtlighet, jødefiendtlig, jødefiendtlige, jødefiendtligheten, jødefiendtligheter, jødefiendtlighetene
Pengejøde: pengejøde, pengejøder, pengejøden, pengejødene, pengejødar, pengejødane
Kommunistjøde: kommunistjøde, kommunistjøden, kommunistjøder, kommunistjødene, kommunistjødar, kommunistjødane, revolusjonsjøde, revolusjonsjøden, revolusjonsjøder, revolusjonsjødene, revolusjonsjødar, revolusjonsjødane, revolutionsjøde, revolutionsjøden, revolutionsjøder, revolutionsjødene, revolutionsjødar, revolutionsjødane
Jødevennlig: jødevennlig, jødevennlige
Jødemakt: jødemakt, jødemakten, jødemakta
Jødepolitikken: jødepolitikk, jødepolitikken, jødepolitikker, jødepolitikkene
Jødeinvasjon: jødeinvasjon, jødeinvasjonen, jødeinvasjonene, jødeinvasjoner
Jødeinnvandring: jødeinnvandring, jødeinnvandringen, jødeinnvandringer, jødeinnvandringene, jødeinnvandrer, jødeinnvandrerne, jødeinnvandrere, jødeinnvandreren, jødeinnvandrerene
Jødenese: jødenese, jødenesen, jødenesene, jødeneser""".split('\n')
jødegrupper = dict()
for x in jødedata:
    d = x.split(':')
    jødegrupper[d[0].strip()] = [w.strip() for w in d[1].split(',')] + [w.strip().capitalize() for w in d[1].split(',')]
jødegrupper
# Out:
# {'Antijødisk': ['antijødisk',
#   'antijødiske',
#   'anti-jødisk',
#   'anti-jødiske',
#   'Antijødisk',
#   'Antijødiske',
#   'Anti-jødisk',
#   'Anti-jødiske'],
#  'Jøde': ['jøde',
#   'jøder',
#   'jøden',
#   'jødene',
#   'jødisk',
#   'jødiske',
#   'jødar',
#   'jødane',
#   'jødedom',
#   'jødedommen',
#   'Jøde',
#   'Jøder',
#   'Jøden',
#   'Jødene',
#   'Jødisk',
#   'Jødiske',
#   'Jødar',
#   'Jødane',
#   'Jødedom',
#   'Jødedommen'],
#  'Jødebolsjevik': ['jødebolsjevik',
#   'jødebolsjevikene',
#   'jødebolsjeviken',
#   'jødebolsjeviker',
#   'bolsjevikjøde',
#   'bolsjevikjøder',
#   'bolsjevikjødene',
#   'bolsjevikjøden',
#   'bolsjevikjødar',
#   'bolsjevikjødane',
#   'Jødebolsjevik',
#   'Jødebolsjevikene',
#   'Jødebolsjeviken',
#   'Jødebolsjeviker',
#   'Bolsjevikjøde',
#   'Bolsjevikjøder',
#   'Bolsjevikjødene',
#   'Bolsjevikjøden',
#   'Bolsjevikjødar',
#   'Bolsjevikjødane'],
#  'Jødeforfølgelse': ['jødeforfølgelse',
#   'jødeforfølgelsen',
#   'jødeforfølgelser',
#   'jødeforfølgelsene',
#   'Jødeforfølgelse',
#   'Jødeforfølgelsen',
#   'Jødeforfølgelser',
#   'Jødeforfølgelsene'],
#  'Jødehat': ['jødehat',
#   'jødehatet',
#   'jødehater',
#   'jødehateren',
#   'jødehaterne',
#   'jødefiendtlighet',
#   'jødefiendtlig',
#   'jødefiendtlige',
#   'jødefiendtligheten',
#   'jødefiendtligheter',
#   'jødefiendtlighetene',
#   'Jødehat',
#   'Jødehatet',
#   'Jødehater',
#   'Jødehateren',
#   'Jødehaterne',
#   'Jødefiendtlighet',
#   'Jødefiendtlig',
#   'Jødefiendtlige',
#   'Jødefiendtligheten',
#   'Jødefiendtligheter',
#   'Jødefiendtlighetene'],
#  'Jødeinnvandring': ['jødeinnvandring',
#   'jødeinnvandringen',
#   'jødeinnvandringer',
#   'jødeinnvandringene',
#   'jødeinnvandrer',
#   'jødeinnvandrerne',
#   'jødeinnvandrere',
#   'jødeinnvandreren',
#   'jødeinnvandrerene',
#   'Jødeinnvandring',
#   'Jødeinnvandringen',
#   'Jødeinnvandringer',
#   'Jødeinnvandringene',
#   'Jødeinnvandrer',
#   'Jødeinnvandrerne',
#   'Jødeinnvandrere',
#   'Jødeinnvandreren',
#   'Jødeinnvandrerene'],
#  'Jødeinvasjon': ['jødeinvasjon',
#   'jødeinvasjonen',
#   'jødeinvasjonene',
#   'jødeinvasjoner',
#   'Jødeinvasjon',
#   'Jødeinvasjonen',
#   'Jødeinvasjonene',
#   'Jødeinvasjoner'],
#  'Jødekapital': ['jødekapital',
#   'jødekapitalen',
#   'jødekapitalist',
#   'jødekapitalistene',
#   'jødekapitalister',
#   'Jødekapital',
#   'Jødekapitalen',
#   'Jødekapitalist',
#   'Jødekapitalistene',
#   'Jødekapitalister'],
#  'Jødemakt': ['jødemakt',
#   'jødemakten',
#   'jødemakta',
#   'Jødemakt',
#   'Jødemakten',
#   'Jødemakta'],
#  'Jødenese': ['jødenese',
#   'jødenesen',
#   'jødenesene',
#   'jødeneser',
#   'Jødenese',
#   'Jødenesen',
#   'Jødenesene',
#   'Jødeneser'],
#  'Jødepolitikken': ['jødepolitikk',
#   'jødepolitikken',
#   'jødepolitikker',
#   'jødepolitikkene',
#   'Jødepolitikk',
#   'Jødepolitikken',
#   'Jødepolitikker',
#   'Jødepolitikkene'],
#  'Jødeproblemet': ['jødeproblem',
#   'jødeproblemet',
#   'jødeproblemene',
#   'jødespørsmål',
#   'jødespørsmålet',
#   'jødespørsmålene',
#   'jødefare',
#   'jødefaren',
#   'jødefarene',
#   'jødefarer',
#   'Jødeproblem',
#   'Jødeproblemet',
#   'Jødeproblemene',
#   'Jødespørsmål',
#   'Jødespørsmålet',
#   'Jødespørsmålene',
#   'Jødefare',
#   'Jødefaren',
#   'Jødefarene',
#   'Jødefarer'],
#  'Jødevennlig': ['jødevennlig', 'jødevennlige', 'Jødevennlig', 'Jødevennlige'],
#  'Jødinne': ['jødinne',
#   'jødinnen',
#   'jødinnene',
#   'jødinner',
#   'jødinna',
#   'Jødinne',
#   'Jødinnen',
#   'Jødinnene',
#   'Jødinner',
#   'Jødinna'],
#  'Kommunistjøde': ['kommunistjøde',
#   'kommunistjøden',
#   'kommunistjøder',
#   'kommunistjødene',
#   'kommunistjødar',
#   'kommunistjødane',
#   'revolusjonsjøde',
#   'revolusjonsjøden',
#   'revolusjonsjøder',
#   'revolusjonsjødene',
#   'revolusjonsjødar',
#   'revolusjonsjødane',
#   'revolutionsjøde',
#   'revolutionsjøden',
#   'revolutionsjøder',
#   'revolutionsjødene',
#   'revolutionsjødar',
#   'revolutionsjødane',
#   'Kommunistjøde',
#   'Kommunistjøden',
#   'Kommunistjøder',
#   'Kommunistjødene',
#   'Kommunistjødar',
#   'Kommunistjødane',
#   'Revolusjonsjøde',
#   'Revolusjonsjøden',
#   'Revolusjonsjøder',
#   'Revolusjonsjødene',
#   'Revolusjonsjødar',
#   'Revolusjonsjødane',
#   'Revolutionsjøde',
#   'Revolutionsjøden',
#   'Revolutionsjøder',
#   'Revolutionsjødene',
#   'Revolutionsjødar',
#   'Revolutionsjødane'],
#  'Pengejøde': ['pengejøde',
#   'pengejøder',
#   'pengejøden',
#   'pengejødene',
#   'pengejødar',
#   'pengejødane',
#   'Pengejøde',
#   'Pengejøder',
#   'Pengejøden',
#   'Pengejødene',
#   'Pengejødar',
#   'Pengejødane']}

# %%
jødeord = [w for g in jødegrupper.values() for w in g]
jødeord
# Out:
# ['jødehat',
#  'jødehatet',
#  'jødehater',
#  'jødehateren',
#  'jødehaterne',
#  'jødefiendtlighet',
#  'jødefiendtlig',
#  'jødefiendtlige',
#  'jødefiendtligheten',
#  'jødefiendtligheter',
#  'jødefiendtlighetene',
#  'Jødehat',
#  'Jødehatet',
#  'Jødehater',
#  'Jødehateren',
#  'Jødehaterne',
#  'Jødefiendtlighet',
#  'Jødefiendtlig',
#  'Jødefiendtlige',
#  'Jødefiendtligheten',
#  'Jødefiendtligheter',
#  'Jødefiendtlighetene',
#  'pengejøde',
#  'pengejøder',
#  'pengejøden',
#  'pengejødene',
#  'pengejødar',
#  'pengejødane',
#  'Pengejøde',
#  'Pengejøder',
#  'Pengejøden',
#  'Pengejødene',
#  'Pengejødar',
#  'Pengejødane',
#  'jødenese',
#  'jødenesen',
#  'jødenesene',
#  'jødeneser',
#  'Jødenese',
#  'Jødenesen',
#  'Jødenesene',
#  'Jødeneser',
#  'kommunistjøde',
#  'kommunistjøden',
#  'kommunistjøder',
#  'kommunistjødene',
#  'kommunistjødar',
#  'kommunistjødane',
#  'revolusjonsjøde',
#  'revolusjonsjøden',
#  'revolusjonsjøder',
#  'revolusjonsjødene',
#  'revolusjonsjødar',
#  'revolusjonsjødane',
#  'revolutionsjøde',
#  'revolutionsjøden',
#  'revolutionsjøder',
#  'revolutionsjødene',
#  'revolutionsjødar',
#  'revolutionsjødane',
#  'Kommunistjøde',
#  'Kommunistjøden',
#  'Kommunistjøder',
#  'Kommunistjødene',
#  'Kommunistjødar',
#  'Kommunistjødane',
#  'Revolusjonsjøde',
#  'Revolusjonsjøden',
#  'Revolusjonsjøder',
#  'Revolusjonsjødene',
#  'Revolusjonsjødar',
#  'Revolusjonsjødane',
#  'Revolutionsjøde',
#  'Revolutionsjøden',
#  'Revolutionsjøder',
#  'Revolutionsjødene',
#  'Revolutionsjødar',
#  'Revolutionsjødane',
#  'jødeforfølgelse',
#  'jødeforfølgelsen',
#  'jødeforfølgelser',
#  'jødeforfølgelsene',
#  'Jødeforfølgelse',
#  'Jødeforfølgelsen',
#  'Jødeforfølgelser',
#  'Jødeforfølgelsene',
#  'jødebolsjevik',
#  'jødebolsjevikene',
#  'jødebolsjeviken',
#  'jødebolsjeviker',
#  'bolsjevikjøde',
#  'bolsjevikjøder',
#  'bolsjevikjødene',
#  'bolsjevikjøden',
#  'bolsjevikjødar',
#  'bolsjevikjødane',
#  'Jødebolsjevik',
#  'Jødebolsjevikene',
#  'Jødebolsjeviken',
#  'Jødebolsjeviker',
#  'Bolsjevikjøde',
#  'Bolsjevikjøder',
#  'Bolsjevikjødene',
#  'Bolsjevikjøden',
#  'Bolsjevikjødar',
#  'Bolsjevikjødane',
#  'antijødisk',
#  'antijødiske',
#  'anti-jødisk',
#  'anti-jødiske',
#  'Antijødisk',
#  'Antijødiske',
#  'Anti-jødisk',
#  'Anti-jødiske',
#  'jøde',
#  'jøder',
#  'jøden',
#  'jødene',
#  'jødisk',
#  'jødiske',
#  'jødar',
#  'jødane',
#  'jødedom',
#  'jødedommen',
#  'Jøde',
#  'Jøder',
#  'Jøden',
#  'Jødene',
#  'Jødisk',
#  'Jødiske',
#  'Jødar',
#  'Jødane',
#  'Jødedom',
#  'Jødedommen',
#  'jødevennlig',
#  'jødevennlige',
#  'Jødevennlig',
#  'Jødevennlige',
#  'jødeinvasjon',
#  'jødeinvasjonen',
#  'jødeinvasjonene',
#  'jødeinvasjoner',
#  'Jødeinvasjon',
#  'Jødeinvasjonen',
#  'Jødeinvasjonene',
#  'Jødeinvasjoner',
#  'jødemakt',
#  'jødemakten',
#  'jødemakta',
#  'Jødemakt',
#  'Jødemakten',
#  'Jødemakta',
#  'jødeinnvandring',
#  'jødeinnvandringen',
#  'jødeinnvandringer',
#  'jødeinnvandringene',
#  'jødeinnvandrer',
#  'jødeinnvandrerne',
#  'jødeinnvandrere',
#  'jødeinnvandreren',
#  'jødeinnvandrerene',
#  'Jødeinnvandring',
#  'Jødeinnvandringen',
#  'Jødeinnvandringer',
#  'Jødeinnvandringene',
#  'Jødeinnvandrer',
#  'Jødeinnvandrerne',
#  'Jødeinnvandrere',
#  'Jødeinnvandreren',
#  'Jødeinnvandrerene',
#  'jødepolitikk',
#  'jødepolitikken',
#  'jødepolitikker',
#  'jødepolitikkene',
#  'Jødepolitikk',
#  'Jødepolitikken',
#  'Jødepolitikker',
#  'Jødepolitikkene',
#  'jødinne',
#  'jødinnen',
#  'jødinnene',
#  'jødinner',
#  'jødinna',
#  'Jødinne',
#  'Jødinnen',
#  'Jødinnene',
#  'Jødinner',
#  'Jødinna',
#  'jødeproblem',
#  'jødeproblemet',
#  'jødeproblemene',
#  'jødespørsmål',
#  'jødespørsmålet',
#  'jødespørsmålene',
#  'jødefare',
#  'jødefaren',
#  'jødefarene',
#  'jødefarer',
#  'Jødeproblem',
#  'Jødeproblemet',
#  'Jødeproblemene',
#  'Jødespørsmål',
#  'Jødespørsmålet',
#  'Jødespørsmålene',
#  'Jødefare',
#  'Jødefaren',
#  'Jødefarene',
#  'Jødefarer',
#  'jødekapital',
#  'jødekapitalen',
#  'jødekapitalist',
#  'jødekapitalistene',
#  'jødekapitalister',
#  'Jødekapital',
#  'Jødekapitalen',
#  'Jødekapitalist',
#  'Jødekapitalistene',
#  'Jødekapitalister']

# %% [markdown]
# # Check trend lines for test_word
#
# Trend lines are relativized over hi frequency words, here coordination 'og' (= and), period ('.') and preposition 'i' (in).

# %%
total_avis.loc['1900':].plot(figsize=(15,5))

# %% [markdown]
# ## Fetch data over periods
#
# The following cells define periods, and fetch a set of concordances for each.

# %%
ypairs = periods(1918, 1960, 22)

print(ypairs)
pair_keys = ["{f}-{t}".format(f=x[0],t=x[1]) for  x in ypairs]
print(pair_keys)
# Out:
# [(1918, 1940)]
# ['1918-1940']

# %% [markdown]
# # Build concordances over periods
#
# Parameters are corpus type (here it is pointing to the value of variable _corpus_ that was set in the beginning togethere with *test_word*

# %%
# Hele datasettet legges i variabelen mns

mns = dict()

# loop gjennom hver periode og hent ut konkordanser
words = jødeord
for (yf, yt) in ypairs:
    konken = []
    for w in words:
        konk = get_konk(
        w, kind='json', params = {
        'corpus':'avis',
            
        'before':18,
        'after':18,
        'size':400000,
        'offset':0,
        'yearfrom':yf, 
        'yearto':yt})
        print(w, len(konk))
        konken += konk
    mns[(yf, yt)] = konken
# Out:
# jødehat 129
# jødehatet 99
# jødehater 25
# jødehateren 16
# jødehaterne 2
# jødefiendtlighet 4
# jødefiendtlig 37
# jødefiendtlige 140
# jødefiendtligheten 0
# jødefiendtligheter 0
# jødefiendtlighetene 1
# Jødehat 14
# Jødehatet 40
# Jødehater 2
# Jødehateren 7
# Jødehaterne 3
# Jødefiendtlighet 0
# Jødefiendtlig 9
# Jødefiendtlige 31
# Jødefiendtligheten 0
# Jødefiendtligheter 0
# Jødefiendtlighetene 0
# pengejøde 0
# pengejøder 11
# pengejøden 0
# pengejødene 9
# pengejødar 0
# pengejødane 1
# Pengejøde 0
# Pengejøder 0
# Pengejøden 0
# Pengejødene 1
# Pengejødar 1
# Pengejødane 1
# jødenese 4
# jødenesen 0
# jødenesene 0
# jødeneser 1
# Jødenese 0
# Jødenesen 1
# Jødenesene 0
# Jødeneser 0
# kommunistjøde 0
# kommunistjøden 0
# kommunistjøder 0
# kommunistjødene 0
# kommunistjødar 0
# kommunistjødane 0
# revolusjonsjøde 0
# revolusjonsjøden 5
# revolusjonsjøder 1
# revolusjonsjødene 1
# revolusjonsjødar 0
# revolusjonsjødane 0
# revolutionsjøde 0
# revolutionsjøden 0
# revolutionsjøder 0
# revolutionsjødene 0
# revolutionsjødar 0
# revolutionsjødane 0
# Kommunistjøde 0
# Kommunistjøden 0
# Kommunistjøder 0
# Kommunistjødene 0
# Kommunistjødar 0
# Kommunistjødane 0
# Revolusjonsjøde 0
# Revolusjonsjøden 1
# Revolusjonsjøder 0
# Revolusjonsjødene 0
# Revolusjonsjødar 0
# Revolusjonsjødane 0
# Revolutionsjøde 0
# Revolutionsjøden 0
# Revolutionsjøder 0
# Revolutionsjødene 0
# Revolutionsjødar 0
# Revolutionsjødane 0
# jødeforfølgelse 96
# jødeforfølgelsen 76
# jødeforfølgelser 247
# jødeforfølgelsene 297
# Jødeforfølgelse 27
# Jødeforfølgelsen 34
# Jødeforfølgelser 46
# Jødeforfølgelsene 97
# jødebolsjevik 1
# jødebolsjevikene 0
# jødebolsjeviken 1
# jødebolsjeviker 0
# bolsjevikjøde 5
# bolsjevikjøder 1
# bolsjevikjødene 5
# bolsjevikjøden 1
# bolsjevikjødar 0
# bolsjevikjødane 0
# Jødebolsjevik 0
# Jødebolsjevikene 0
# Jødebolsjeviken 0
# Jødebolsjeviker 0
# Bolsjevikjøde 0
# Bolsjevikjøder 0
# Bolsjevikjødene 0
# Bolsjevikjøden 4
# Bolsjevikjødar 0
# Bolsjevikjødane 0
# antijødisk 14
# antijødiske 86
# anti-jødisk 4
# anti-jødiske 20
# Antijødisk 0
# Antijødiske 2
# Anti-jødisk 1
# Anti-jødiske 0
# jøde 3792
# jøder 8599
# jøden 1078
# jødene 6061
# jødisk 3113
# jødiske 8304
# jødar 286
# jødane 363
# jødedom 235
# jødedommen 378
# Jøde 945
# Jøder 1157
# Jøden 576
# Jødene 1671
# Jødisk 432
# Jødiske 828
# Jødar 19
# Jødane 79
# Jødedom 34
# Jødedommen 64
# jødevennlig 5
# jødevennlige 5
# Jødevennlig 0
# Jødevennlige 1
# jødeinvasjon 2
# jødeinvasjonen 5
# jødeinvasjonene 0
# jødeinvasjoner 0
# Jødeinvasjon 1
# Jødeinvasjonen 1
# Jødeinvasjonene 0
# Jødeinvasjoner 0
# jødemakt 1
# jødemakten 0
# jødemakta 0
# Jødemakt 0
# Jødemakten 0
# Jødemakta 0
# jødeinnvandring 2
# jødeinnvandringen 8
# jødeinnvandringer 0
# jødeinnvandringene 0
# jødeinnvandrer 0
# jødeinnvandrerne 0
# jødeinnvandrere 0
# jødeinnvandreren 0
# jødeinnvandrerene 0
# Jødeinnvandring 0
# Jødeinnvandringen 1
# Jødeinnvandringer 0
# Jødeinnvandringene 0
# Jødeinnvandrer 0
# Jødeinnvandrerne 0
# Jødeinnvandrere 0
# Jødeinnvandreren 0
# Jødeinnvandrerene 0
# jødepolitikk 15
# jødepolitikken 4
# jødepolitikker 0
# jødepolitikkene 0
# Jødepolitikk 1
# Jødepolitikken 3
# Jødepolitikker 0
# Jødepolitikkene 0
# jødinne 241
# jødinnen 39
# jødinnene 11
# jødinner 78
# jødinna 3
# Jødinne 21
# Jødinnen 145
# Jødinnene 11
# Jødinner 7
# Jødinna 1
# jødeproblem 43
# jødeproblemet 140
# jødeproblemene 2
# jødespørsmål 40
# jødespørsmålet 346
# jødespørsmålene 0
# jødefare 1
# jødefaren 2
# jødefarene 0
# jødefarer 0
# Jødeproblem 11
# Jødeproblemet 77
# Jødeproblemene 0
# Jødespørsmål 5
# Jødespørsmålet 127
# Jødespørsmålene 0
# Jødefare 0
# Jødefaren 2
# Jødefarene 0
# Jødefarer 0
# jødekapital 20
# jødekapitalen 19
# jødekapitalist 0
# jødekapitalistene 2
# jødekapitalister 1
# Jødekapital 0
# Jødekapitalen 2
# Jødekapitalist 0
# Jødekapitalistene 0
# Jødekapitalister 0

# %%
jødekonk = mns[(1918,1940)]

# %%
len(jødekonk)
# Out:
# 41128

# %%
HTML(konk_to_html(jødekonk[:100]))
# Out:
# <table><tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19320416_40_88_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19320416_40_88_1</a><td>denne maten har tatt Kristus * 11 inntekt for nasjonalsosialistenes rasehat og</td><td>jødehat</td><td style='text-align:left'>. Så fantastisk som det enn kan høres , • * •</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19220629_30_147_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19220629_30_147_1</a><td>ogsaa for tiden i Tyskland inden den jevne del av befolkningen et</td><td>jødehat</td><td style='text-align:left'>, som kun er forstaaelig ut fra den fortvilede stilling det tyske</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19350306_43_55_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19350306_43_55_1</a><td>patriot vød utsikter til spetikler eller alagsmil med landsmenn ! Man taler</td><td>jødehat</td><td style='text-align:left'>, håner den kristne kultur , agiterer mot all humanisme — altså</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19290406_163_80_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19290406_163_80_1</a><td>Alexandria grep med lysten glede en ny årsak til å vise sitt</td><td>jødehat</td><td style='text-align:left'>. De regnet med keiserens bifall til en jødeforfølgelse . Egyptens statholder</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19300507_164_105_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_adresseavisen_null_null_19300507_

# %%
jødekonk = sorted(jødekonk[:], key=lambda x: x['urn'].split('_')[-4])

# %%
jødekonk[0]
# Out:
# {'after': '. Elverum foran Den nye reUkrivningen . Vor a ; rtikel forleden',
#  'before': 'torsdag 3 , farmar 191 g Nr . 2 Striden bland byens',
#  'urn': 'https://beta.nb.no/items/URN:NBN:no-nb_digavis_dagbladet_null_null_19180103_51_2_1',
#  'word': 'jøder'}

# %%
pdnew = conc_count(mns[(1918,1940)])
#set1 = check_words(pdnew, 'fascister bolsjeviker kommunister nazister demokrater regjeringer'.split())
#set2 = check_words(pdnew, "Norge Sverige Storbritannia Tyskland Russland Frankrike Danmark Polen Finland Amerika".split())
gruppe1 = check_words2(pdnew, "Talmud Tora talmud tora moselov moses mosaisk bibel skrifter bud påbud forbud lydighet semitisk Gud lov teokrat".split())
gruppe2 = check_words2(pdnew, "Marx Lasalle Trotski sosialist socialist sosialisten socialisten sosialister socialister sosialistene socialistene kommunist kommunisten kommunister kommunistene bolsjeviksocialisme socialdemokrat revolusjon \
komintern sovject arbeider proletar".split())
gruppe3 = check_words2(pdnew, "Kapital, kapital, handle, penge, penger, rente, \
rentefod, rentefot, aager/åger, rigdom, magt, rige, amerikansk, amerikanisme, gull, guld, sølv, laane, udlaan, pant, forretninger, finans, finansskandale, bank, børs, aksje, bedrageri".split(', '))
gruppe4 = check_words2(pdnew, "blodskam, kjønn, moral, seksual, erotiske, \
sedelighetsforbrytelse, forfører, barneoppdragelse, bordell, \
ekteskapsbrudd, ekteskap, pornografi, pornografisk, pornografiske, Reich, Freud, kvinde, skjænde, usædelig, usedelig, jomfru, hustru, leiermaal".split(', '))
gruppe5 = check_words2(pdnew, "stat, staten, internasjonal, kosmopolitt, verdensherredømme, Zions, Zionist, vesen, natur, egenskap, hemmelig, skjule, usynlig, frimurer, losje, allianse, rase, raseblanding, arvelighet, blod, bastard, blanding".split(', '))

# %%
show_gruppe(gruppe1)
# Out:
#                  0
# Talmud    9.037461
# mosaisk   8.477742
# talmud    8.110959
# semitisk  7.140707
# skrifter  3.159274
# bibel     2.772480
# forbud    2.380746
# påbud     2.311395
# lydighet  1.818966
# lov       1.657216
# Gud       1.398590
# bud       0.624224
# tora      0.599395
# Tora     -0.517617
# moselov       -inf
# moses         -inf
# teokrat        NaN

# %%
show_gruppe(gruppe2)
# Out:
#                             0
# Lasalle              5.110959
# sosialister          4.421888
# proletar             4.139142
# Marx                 3.968295
# kommunister          3.688342
# sosialist            3.487862
# kommunist            3.231376
# sosialistene         3.146000
# revolusjon           2.844746
# Trotski              2.794193
# socialister          2.430876
# socialist            2.421128
# kommunistene         1.810886
# kommunisten          1.729107
# socialisten          1.467103
# socialistene         1.309597
# arbeider             0.576388
# sosialisten              -inf
# komintern                -inf
# socialdemokrat           -inf
# bolsjeviksocialisme       NaN
# sovject                   NaN

# %%
show_gruppe(gruppe3)
# Out:
#                        0
# amerikanisme    6.043845
# forretninger    4.382334
# finansskandale  4.333352
# finans          3.746569
# handle          2.397911
# kapital         1.983315
# penger          1.300463
# rige            1.204191
# amerikansk      1.146206
# bedrageri       0.833695
# rigdom          0.655045
# magt            0.480413
# gull            0.237894
# penge           0.163806
# guld           -0.005632
# bank           -0.298801
# laane          -0.441435
# børs           -0.469232
# sølv           -0.543847
# rente          -1.143657
# Kapital        -1.276032
# pant           -1.324711
# aksje          -2.029871
# rentefot            -inf
# rentefod            -inf
# udlaan              -inf
# aager/åger           NaN

# %%
show_gruppe(gruppe4)
# Out:
#                                0
# seksual                 5.163427
# pornografisk            4.458882
# pornografiske           4.303604
# Freud                   4.216141
# blodskam                3.914562
# forfører                3.590387
# Reich                   3.163427
# ekteskap                2.867574
# moral                   2.425585
# usedelig                2.367567
# erotiske                1.379155
# jomfru                  0.863303
# kjønn                   0.768821
# hustru                  0.191001
# kvinde                 -0.351851
# leiermaal                   -inf
# pornografi                  -inf
# ekteskapsbrudd              -inf
# sedelighetsforbrytelse      -inf
# bordell                     -inf
# skjænde                     -inf
# barneoppdragelse            -inf
# usædelig                    -inf

# %%
show_gruppe(gruppe5)
# Out:
#                           0
# verdensherredømme  7.535844
# Zions              6.875428
# rase               5.520609
# raseblanding       5.231814
# kosmopolitt        4.632912
# blod               4.148677
# frimurer           3.107742
# stat               2.940989
# blanding           2.307105
# bastard            2.133679
# hemmelig           2.124632
# internasjonal      2.018408
# vesen              1.533432
# egenskap           0.800563
# allianse           0.762653
# staten             0.652458
# natur              0.183922
# skjule             0.021477
# losje             -0.050113
# arvelighet             -inf
# usynlig                -inf
# Zionist                -inf

# %%
show_gruppe(gruppe6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-618dcc06e16c> in <module>()
# ----> 1 show_gruppe(gruppe6)
#
# NameError: name 'gruppe6' is not defined

# %% [markdown]
# ### Sampling fra konkordansen

# %%
import numpy as np

# %%
# velg 10 pr.år
res = []
g = lambda x: x['urn'].split('_')[-4][:4] 
for year in range(1918, 1941):
        yearkonk = [x for x in jødekonk if g(x) == str(year)]
        #print(yearkonk[:1])
        for i in range(10):
            res.append( np.random.choice(yearkonk)) 
HTML(konk_to_html(res))
# Out:
# <table><tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19181130_59_604_2' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19181130_59_604_2</a><td>egte bayersk af . stamning , medens Eisner er en > østgaliziek</td><td>jøde</td><td style='text-align:left'>, hvis navn er Sar lomon Knsnovski . Dr. Hofacker . •</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19190201_27_27_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19190201_27_27_1</a><td>harme over cle unge strejkeledere , ' » om tildels er russisko</td><td>jøder</td><td style='text-align:left'>, inficeret av bolsjevikiske ideer , og som er Klit til en</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19190308_101_129_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19190308_101_129_1</a><td>Wilsons tflorsikr inger om at op rette Palass tin a som et</td><td>jødisk</td><td style='text-align:left'>nationalt kjernsted , . Hovedfioinslatgenie lyder ; © aafedesi : iS £</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19191217_60_621_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19191217_60_621_1</a><td>' . ' til den kunde ventes i næste øicblik . En</td><td>jøde</td><td style='text-align:left'>, , som følte ' sig sort en . paTia " fra</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_nordlandsavis_null_null_19190116_27_4_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_nordlandsavis_null_null_19190116_27_4_1</a><td>kr . Øog til belysning i Risøsund 7500 kr . Den evige</td><td>jøde</td><td style='text-align:left'>! Paris : Det forlyder at fredskonferancen ventes fjerdig i mars ,</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19190101_102_1_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_morgenbladet_null_null_19190101_102_1_1</a><td>paa polakkerne . , Derpaa begyndte dér en trommeild mot hvor de</td><td>jødiske</td><td style='text-align:left'>indbyggere var forsamlét til bøn . Senere stormet tusener av bevæbnede polakker</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_trondhjemsadresseavis_null_null_19200206_154_31_1' target='_'>htt

# %%
with open('jødesample.html','w',encoding= 'utf-8') as js:
    js.write(konk_to_html(res))

# %%
HTML(konk_to_html(
    np.random.choice([x for x in jødekonk if x['word'] == 'jøde' or x['word'] == 'Jøde' ], 50)
))
# Out:
# <table><tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_norgeskommunistblad_null_null_19240219_3_42_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_norgeskommunistblad_null_null_19240219_3_42_1</a><td>huske at Kristus , som han her tar til inntekt , var</td><td>jøde</td><td style='text-align:left'>. Og Abraham var ogsaa jenk . Og alle patriarkens . Jeg</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19380718_79_351_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19380718_79_351_1</a><td>dementier feies til side som « uvedkommende » . soldat og en</td><td>jøde</td><td style='text-align:left'>fra hjelpetrcnet blev alvorlig såret . Araberne fra denne landsby skal i</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19190712_60_340_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19190712_60_340_1</a><td>, vor kjære liir , svigerfar o < i bedstefar Julius_ Noer</td><td>Jøde</td><td style='text-align:left'>idair , 72 aar camrnel . Noer i R raml val ,</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19221223_30_299_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19221223_30_299_1</a><td>tjwre mand > g mm ' ar aTsMWH Nils Wlige 6 nmoes</td><td>Jøde</td><td style='text-align:left'>amtSj I « ar gamuiel . \ | « • » ,</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19210222_62_89_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_aftenposten_null_null_19210222_62_89_1</a><td>gammeltestamentlige profeters høie patos 1 hans udødelige ord : " Har en</td><td>jøde</td><td style='text-align:left'>ikke øine ? har en jøde ingen hænder , lemmer , ledemod</td></tr>
# <tr><td><a href='https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavangeraftenblad_null_null_19390313_47_62_1' target='_'>https://beta.nb.no/items/URN:NBN:no-nb_digavis_stavang

# %%
with open ('jødekonkordanser.html','w', encoding='utf-8') as j:
    j.write(konk_to_html(jødekonk))

# %%
{x['word'] for x in jødekonk}
# Out:
# {'Anti-jødisk',
#  'Antijødiske',
#  'Bolsjevikjøden',
#  'Jødane',
#  'Jødar',
#  'Jøde',
#  'Jødedom',
#  'Jødedommen',
#  'Jødefaren',
#  'Jødefiendtlig',
#  'Jødefiendtlige',
#  'Jødeforfølgelse',
#  'Jødeforfølgelsen',
#  'Jødeforfølgelsene',
#  'Jødeforfølgelser',
#  'Jødehat',
#  'Jødehater',
#  'Jødehateren',
#  'Jødehaterne',
#  'Jødehatet',
#  'Jødeinnvandringen',
#  'Jødeinvasjon',
#  'Jødeinvasjonen',
#  'Jødekapitalen',
#  'Jøden',
#  'Jødene',
#  'Jødenesen',
#  'Jødepolitikk',
#  'Jødepolitikken',
#  'Jødeproblem',
#  'Jødeproblemet',
#  'Jøder',
#  'Jødespørsmål',
#  'Jødespørsmålet',
#  'Jødevennlige',
#  'Jødinna',
#  'Jødinne',
#  'Jødinnen',
#  'Jødinnene',
#  'Jødinner',
#  'Jødisk',
#  'Jødiske',
#  'Pengejødane',
#  'Pengejødar',
#  'Pengejødene',
#  'Revolusjonsjøden',
#  'anti-jødisk',
#  'anti-jødiske',
#  'antijødisk',
#  'antijødiske',
#  'bolsjevikjøde',
#  'bolsjevikjøden',
#  'bolsjevikjødene',
#  'bolsjevikjøder',
#  'jødane',
#  'jødar',
#  'jøde',
#  'jødebolsjevik',
#  'jødebolsjeviken',
#  'jødedom',
#  'jødedommen',
#  'jødefare',
#  'jødefaren',
#  'jødefiendtlig',
#  'jødefiendtlige',
#  'jødefiendtlighet',
#  'jødefiendtlighetene',
#  'jødeforfølgelse',
#  'jødeforfølgelsen',
#  'jødeforfølgelsene',
#  'jødeforfølgelser',
#  'jødehat',
#  'jødehater',
#  'jødehateren',
#  'jødehaterne',
#  'jødehatet',
#  'jødeinnvandring',
#  'jødeinnvandringen',
#  'jødeinvasjon',
#  'jødeinvasjonen',
#  'jødekapital',
#  'jødekapitalen',
#  'jødekapitalistene',
#  'jødekapitalister',
#  'jødemakt',
#  'jøden',
#  'jødene',
#  'jødenese',
#  'jødeneser',
#  'jødepolitikk',
#  'jødepolitikken',
#  'jødeproblem',
#  'jødeproblemene',
#  'jødeproblemet',
#  'jøder',
#  'jødespørsmål',
#  'jødespørsmålet',
#  'jødevennlig',
#  'jødevennlige',
#  'jødinna',
#  'jødinne',
#  'jødinnen',
#  'jødinnene',
#  'jødinner',
#  'jødisk',
#  'jødiske',
#  'pengejødane',
#  'pengejødene',
#  'pengejøder',
#  'revolusjonsjøden',
#  'revolusjonsjødene',
#  'revolusjonsjøder'}

# %% [markdown]
# ## Antallet aviser og statistikk for perioden

# %%
urns = [x['urn'] for x in jødekonk[:]]
urns[:5]
# Out:
# ['https://beta.nb.no/items/URN:NBN:no-nb_digavis_dagbladet_null_null_19180103_51_2_1',
#  'https://beta.nb.no/items/URN:NBN:no-nb_digavis_trondhjemsadresseavis_null_null_19180104_152_3_1',
#  'https://beta.nb.no/items/URN:NBN:no-nb_digavis_trondhjemsadresseavis_null_null_19180104_152_3_1',
#  'https://beta.nb.no/items/URN:NBN:no-nb_digavis_trondhjemsadresseavis_null_null_19180104_152_3_1',
#  'https://beta.nb.no/items/URN:NBN:no-nb_digavis_trondhjemsadresseavis_null_null_19180104_152_3_1']

# %%
avisnavn = []
antall = Counter()
for urn in urns[:]:
    avisnavn.append(urn.split('_')[2])
antall.update(avisnavn)

# %%
antall.most_common()
# Out:
# [('aftenposten', 11920),
#  ('arbeiderbladetoslo', 5432),
#  ('stavangeraftenblad', 4644),
#  ('adresseavisen', 3392),
#  ('bergensarbeiderblad', 1859),
#  ('morgenbladet', 1304),
#  ('trondhjemsadresseavis', 1213),
#  ('kongsvingerarbeiderblad', 1111),
#  ('sarpsborgarbeiderbla', 927),
#  ('nordlandsavis', 761),
#  ('dagbladet', 759),
#  ('telemarkarbeiderblad', 731),
#  ('dagensnytt', 584),
#  ('norsktidend', 542),
#  ('fremover', 489),
#  ('norgeskvinner', 467),
#  ('askerogbaerumsbudstikke', 420),
#  ('frihetskampen', 403),
#  ('norgeskommunistblad', 379),
#  ('amagasinet', 367),
#  ('tidenstegn', 350),
#  ('inntrondelagen', 334),
#  ('frittfolkoslo', 319),
#  ('nordtrondelagognordenfjeldsktidende', 301),
#  ('firdafolkeblad', 258),
#  ('den17demai', 237),
#  ('nybrott', 232),
#  ('hamararbeiderblad', 173),
#  ('norskeintelligenssedler', 155),
#  ('fylkestidendeforsognogfjordane', 142),
#  ('indtrondelagen', 117),
#  ('indheredsposten', 105),
#  ('hedemarkensamtstidende', 95),
#  ('nordtrondelag', 61),
#  ('flekkefjordsposten', 55),
#  ('nordlandsframtid', 53),
#  ('idrettsliv', 52),
#  ('hirdmannen', 50),
#  ('tronderbladet', 48),
#  ('romsdalsamtstidende', 47),
#  ('arbeidet', 46),
#  ('sunnmoeringensykkylven', 41),
#  ('nordrebergenhusamtstidende', 41),
#  ('nordenfjeldsktidende', 32),
#  ('arbeiderpolitikken', 21),
#  ('selbyggen', 14),
#  ('norskkundgjoerelsestidende', 11),
#  ('daggry', 11),
#  ('tiden', 8),
#  ('gulatidend', 8),
#  ('mosssocialdemokrat', 3),
#  ('indherred', 2),
#  ('nordtrondelaginntrondelagen', 1),
#  ('dunderlandsdoelen', 1)]

# %%
avisnavn_år = []
antall_år = Counter()
for urn in urns[:]:
    avisnavn_år.append((urn.split('_')[2],urn.split('_')[5][:4]))
antall_år.update(avisnavn_år)

# %%
res = dict()
for x in antall_år:
    #print(x)
    if x[0] not in res:
        res[x[0]] = dict()
    res[x[0]][x[1]] = antall_år[x]
df = pd.DataFrame(res)

# %%
heatmap(df.transpose())
# Out:
#         <style  type="text/css" >
#
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col0 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col1 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col2 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col3 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col4 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col5 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col6 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col7 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col8 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col9 {
#
#                 background-color:  #96d396;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col10 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col11 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col12 {
#
#                 background-color:  #4daa4d;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col13 {
#
#                 background-color:  #7ec67e;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col14 {
#
#                 background-color:  #62b662;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col15 {
#
#                 background-color:  #a8dda8;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col16 {
#
#                 background-color:  #bce8bc;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col17 {
#
#                 background-color:  #9ed79e;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col18 {
#
#                 background-color:  #c2ecc2;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col19 {
#
#                 background-color:  #9ed89e;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col20 {
#
#                 background-color:  #9ed79e;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col21 {
#
#                 background-color:  #ade0ad;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row0_col22 {
#
#                 background-color:  #87cb87;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col0 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col1 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col2 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col3 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col4 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col5 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col6 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col7 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col8 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col9 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col10 {
#
#                 background-color:  #058205;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col11 {
#
#                 background-color:  #3aa03a;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col12 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col13 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col14 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col15 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col16 {
#
#                 background-color:  #319b31;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col17 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col18 {
#
#                 background-color:  #5bb25b;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col19 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col20 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col21 {
#
#                 background-color:  #008000;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row1_col22 {
#
#                 background-color:  #168c16;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row2_col0 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row2_col1 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row2_col2 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row2_col3 {
#
#                 background-color:  #e5ffe5;
#
#             }
#
#             #T_b03ac5a4_dae4_11e7_bb96_d4bed96c69c7row2_col4 {
#
#                 background-color:  #e5ffe5;

# %% [markdown]
# # Antall ord totalt pr.år

# %%
total_avis.loc['1918':'1940']
# Out:
#               0
# 1918   81244110
# 1919   85110162
# 1920   64900734
# 1921   62286846
# 1922   67969662
# 1923   64058298
# 1924   81237864
# 1925   75782964
# 1926   75945762
# 1927   85965708
# 1928   86623224
# 1929   91297638
# 1930   70428810
# 1931   78760344
# 1932   80124342
# 1933   95953278
# 1934  102384978
# 1935   87079074
# 1936  114657960
# 1937   88972998
# 1938   96138036
# 1939  104995152
# 1940   68326200

# %% [markdown]
# # Antall ord totalt det er søkt i, tallene i blått

# %%
HTML('<h2 style="color:blue">{a}</h2>'.format(a = str(int(total_avis.loc['1918':'1940'].sum()))))
# Out:
# <h2 style="color:blue">1910244144</h2>

# %% [markdown]
# # Antall ord i konkordansen

# %%
antall_konk = conc_count(mns[(1918,1940)], mode='total')

# %%
HTML('<h2 style="color:blue">{a}</h2>'.format(a = str(sum(antall_konk.values()))))
# Out:
# <h2 style="color:blue">987072</h2>

# %% [markdown]
# Nesten 1 million ord i konkordansen fra en total på nesten 2 milliarder ord for hele korpuset 1918 til 1940.
